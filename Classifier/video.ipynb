# %%
import dlib
import cv2
import face_recognition
import torch
import datetime

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
cap= cv2.VideoCapture("mutaharshort.mp4")

frames = cap.get(cv2.CAP_PROP_FRAME_COUNT)
fps = cap.get(cv2.CAP_PROP_FPS)

# %%
print(fps)
print(frames)
# Out:
# 30.0
# 900.0

# %%
muta_image = face_recognition.load_image_file("muta_1.png")

muta_encode = face_recognition.face_encodings(muta_image)[0]

known_encode = [muta_encode]

known_name = ['Mutahar']

# %%
face_locations = []
num = 0
start = datetime.datetime.now()



while num < int(frames):
    num += 1

    ret, frame = cap.read()

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    face_locations = face_recognition.face_locations(rgb_frame)
    face_encoding = face_recognition.face_encodings(rgb_frame,face_locations)


    print(face_locations[])
    print(face_encoding)

    
    
    for top, right, bottom, left in face_locations:

        # matches = face_recognition.compare_faces(
        # known_encode,
        # face_encoding)
        
        # if True in matches:
        #     first_match_index = matches.index(True)
        #     name = known_face_names[first_match_index]

        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0,  255), 2)

        cv2.putText(frame,name,(left, top - 10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(0, 255, 0)
                    ,2)
 
    #cv2.imwrite(f'frames/frame_{num}.jpg', frame)


totaltime = datetime.datetime.now() - start

print(totaltime)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 14
#      10 ret, frame = cap.read()
#      12 rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
# ---> 14 face_locations = face_recognition.face_locations(rgb_frame)
#      15 face_encoding = face_recognition.face_encodings(rgb_frame,face_locations)
#      18 print(face_locations)
#
# File /opt/venv/lib/python3.12/site-packages/face_recognition/api.py:121, in face_locations(img, number_of_times_to_upsample, model)
#     119     return [_trim_css_to_bounds(_rect_to_css(face.rect), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, "cnn")]
#     120 else:
# ...

# %%
video_seconds = frames/fps
print(video_seconds)
# Out:
# 30.0
