# %%
import requests
import json

url = "http://localhost:11434/api/generate"

# %%
data = {
    "model":"granite4:latest",
    "prompt":"tell me a fact about the roman empire"
}

# %%
response = requests.post(url, json=data, stream=True)

if response.status_code == 200:
    print('Generated text:', end=' ', flush=True)
    for line in response.iter_lines():
        if line:
            decoded_line = line.decode('utf-8')
            result = json.loads(decoded_line)
            generated_text = result.get('response','')
            print(generated_text,end='',flush=True)
else:
    print('Error:', response.status_code, response.text)
# Out:
# Generated text: One interesting fact about the Roman Empire is that it had its own form of early banking. The Romans used clay tablets, called tabulae, to record financial transactions and debts. These tablets were stored in vaults or banks for safekeeping. This system allowed merchants and citizens to store their wealth securely and make payments without carrying large amounts of gold or silver coins with them.
#
# The Roman bank system was known as the "cafrae" (from the Greek word "kleros," meaning share or portion). It provided a way for people to manage their finances, pay taxes, and conduct business transactions more efficiently. The use of these clay tablets also facilitated trade within the empire and beyond its borders.
#
# The Roman banking system was based on principles that are still used in modern banking today, such as the concept of credit, interest rates, and secure storage of assets. This early form of banking played a crucial role in the economic stability and growth of the Roman Empire during its height.
